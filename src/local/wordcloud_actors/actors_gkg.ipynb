# %%
import sys
sys.path.append("..")
from helper import *
# Out:
# /home/karna/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/karna/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
DATA_PATH = "../../data/from_cluster/worldcloud_actors/"

# %% [markdown]
# # Persons

# %%
wordcloud_persons(DATA_PATH,50)

# %% [markdown]
# # Countries

# %%
wordcloud_countries(DATA_PATH,50)

# %% [markdown]
# # Cities

# %%
wordcloud_cities(DATA_PATH,50)

# %% [markdown]
# Note: New York doesn't appear because it is considered as a state and not as a city.

# %% [markdown]
# # Organizations

# %%
wordcloud_organizations(DATA_PATH,50)
