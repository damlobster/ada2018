# %%
# Add your imports here
import datetime
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
persons = pd.read_csv("persons_occurences.csv")

# %%
persons
# Out:
#         Count                          Actor
# 0     2021213                   donald trump
# 1     1465610                   barack obama
# 2      810167                hillary clinton
# 3      784535                    los angeles
# 4      381205                 vladimir putin
# 5      294330                      las vegas
# 6      282963                 bernie sanders
# 7      281551                  george w bush
# 8      272371                     john kerry
# 9      218694                  pacific ocean
# 10     213987                   pope francis
# 11     204075                  angela merkel
# 12     195749               malcolm turnbull
# 13     183833                       ted cruz
# 14     179097                    jerry brown
# 15     170428                 justin trudeau
# 16     168339                  rex tillerson
# 17     166832                      paul ryan
# 18     166114                  narendra modi
# 19     166108                        el nino
# ...
